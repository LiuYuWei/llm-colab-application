# %% [markdown]
# <a href="https://colab.research.google.com/github/LiuYuWei/llm-colab-application/blob/main/Simon_LLM_Application_Google_AI_Studio_GenAISDK_Full_Method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Gen AI SDK - Google AI Studio
#
# google-genai 是用於與 Google 的 Generative AI API 互動的初始 Python 用戶端程式庫。
#
# Google Gen AI Python SDK 為開發人員提供了一個接口，可以將 Google 的生成模型整合到他們的 Python 應用程式中。它支援Gemini 開發者 API和Vertex AI API。

# %% [markdown]
# ## I. Installation and Configure

# %% [markdown]
# #### 透過 pip 安裝 google-genai python package

# %%
# !pip install -q google-genai

# %% [markdown]
# ## II. Import and create a client

# %%
from google import genai
from google.genai import types
from google.colab import userdata

client = genai.Client(api_key=userdata.get('GOOGLE_API_KEY'))

# %% [markdown]
# ## III. API 測試

# %%
response = client.models.generate_content(
    model='gemini-2.5-flash', contents='請問為何天空是藍色的？'
)
print(response.text)
# Out:
# 天空之所以是藍色的，主要原因是 **瑞利散射 (Rayleigh Scattering)** 現象，以及光線在大氣層中的行為：
#
# 1.  **陽光是混合光：** 太陽光看起來是白色的，但它實際上是由所有可見光譜的顏色組成的，從波長最短的紫色、藍色、綠色、黃色、橙色到波長最長的紅色。
#
# 2.  **大氣層的散射：** 當陽光進入地球大氣層時，它會撞擊到空氣中的分子（主要是氮氣和氧氣）以及微小的塵埃顆粒。這些分子和顆粒會將光線向四面八方散射開來。
#
# 3.  **瑞利散射的關鍵：**
#     *   瑞利散射的原理是：**光線的散射程度與其波長的四次方成反比。**
#     *   這意味著，**波長越短的光線，被散射的程度就越劇烈；波長越長的光線，被散射的程度就越弱。**
#
# 4.  **藍光被優先散射：**
#     *   在可見光譜中，藍光和紫光的波長最短。因此，當陽光穿過大氣層時，它們比綠光、黃光、橙光和紅光更容易被空氣分子散射開來。
#     *   由於藍光的散射效率最高，大量藍光從四面八方散射到我們眼睛裡，所以我們看到天空是藍色的。
#
# 5.  **為什麼不是紫色？**
#     *   紫光的波長其實比藍光更短，理論上應該散射得更多。然而，天空看起來卻是藍色而不是紫色，原因有二：
#         1.  **太陽發出的紫光本身就比藍光少。**
#         2.  **人眼對藍光的敏感度遠高於對紫光的敏感度。** 我們的大腦和眼睛對藍光的響應比紫光更強烈。
#
# 6.  **其他顏色的去向：**
#     *   波長較長的光（如紅光、黃光和橙光）由於散射程度較弱，它們能相對直接地穿過大氣層，大部分未被散射，因此散射到我們眼睛裡的就少得多了。
#
# **總結來說：** 天空之所以是藍色的，是因為太陽光中的藍光（以及一部分紫光）在地球大氣層中被空氣分子以瑞利散射的方式優先且劇烈地散射開來，使得藍光從四面八方進入我們的眼睛，讓我們感知到天空的藍色。
#
# **延伸閱讀：**
#
# *   **日出日落為何是紅色？** 當太陽靠近地平線時，陽光需要穿過更厚的大氣層。大部分的藍光和紫光在到達我們眼睛之前就已經被散射開了，只剩下波長較長、散射較少的紅光、橙光和黃光能夠直接穿透大氣層，因此日出日落時天空呈現紅色或橙色。
# *   **雲為何是白色？** 雲是由水滴或冰晶組成的，這些顆粒比空氣分子大得多。它們會以非選擇性的方式（米氏散射，Mie Scattering）散射所有波長的光，而不是像瑞利散射那樣偏好短波長，因此雲看起來是白色的。

# %%
import requests
import json
from google.colab import userdata

# 替換成你的 API 金鑰
GEMINI_API_KEY = userdata.get('GOOGLE_API_KEY')

# API URL
url = f'https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent?key={GEMINI_API_KEY}'

# 請求資料
payload = {
    "contents": [
        {
            "parts": [
                {
                    "text": "請問為何天空是藍色的？"
                }
            ]
        }
    ]
}

# 設定標頭
headers = {
    'Content-Type': 'application/json'
}

# 發送 POST 請求
response = requests.post(url, headers=headers, data=json.dumps(payload))

# 檢查回應
if response.status_code == 200:
    result = response.json()
    print(json.dumps(result, indent=2, ensure_ascii=False))
else:
    print(f'錯誤：{response.status_code}')
    print(response.text)
# Out:
# {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "天空是藍色的，主要原因是 **瑞利散射 (Rayleigh scattering)**。\n\n以下是詳細解釋：\n\n* **太陽光包含各種顏色的光：** 太陽光並非單一顏色，而是由各種顏色的光組成，包括紅、橙、黃、綠、藍、靛、紫。\n\n* **空氣中的微粒：** 大氣層中充滿了非常微小的粒子，例如氮氣和氧氣分子。\n\n* **瑞利散射：** 當太陽光穿過大氣層時，這些微小的粒子會散射光線。 瑞利散射的特性是，**波長較短的光更容易被散射**。\n\n* **藍光更容易被散射：** 因為藍光和紫光的波長較短，所以它們比其他顏色的光更容易被空氣中的微粒散射。\n\n* **我們看到的是散射後的藍光：** 這些散射後的藍光在天空四處漫射，因此我們從任何角度看天空，都能看到藍色的光，所以天空看起來是藍色的。\n\n**為什麼不是紫色的？**\n\n雖然紫光的波長更短，更容易被散射，但實際上，太陽光中紫光的含量比藍光少，而且我們眼睛對紫光的敏感度也比藍光低。 因此，最終散射到我們眼中的光線中，藍光的比重更高，所以我們看到的是藍色的天空，而不是紫色的。\n\n**其他情況：**\n\n* **日落時天空為什麼是紅色的？** 當太陽接近地平線時，太陽光必須穿過更厚的大氣層才能到達我們的眼睛。 在這個過程中，更多的藍光被散射掉，剩下的主要是紅光和橙光，因此我們看到的日落是紅色的。\n\n* **沒有大氣層的星球天空是什麼顏色？**  例如月球，因為沒有大氣層，所以沒有瑞利散射，天空會是黑色的，即使在白天也能看到星星。\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.3443432164026247
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 7,
#     "candidatesTokenCount": 431,
#     "totalTokenCount": 438,
#     "promptTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 7
#       }
#     ],
#     "candidatesTokensDetails": [
#       {
#         "modality": "TEXT",
#         "tokenCount": 431
#       }
#     ]
#   },
#   "modelVersion": "gemini-2.0-flash",
#   "responseId": "64mgaMmTApCzgLUPsobdqA4"
# }

# %% [markdown]
# ## IV. 上傳檔案後使用 API
#
# 你可以透過 API 上傳檔案，並且對檔案進行 AI 的問答。

# %%
# !wget -q https://storage.googleapis.com/generativeai-downloads/data/a11.txt

# %%
file = client.files.upload(file='a11.txt')
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents=['你可以使用繁體中文幫我統整此內容嗎？', file]
)
print(response.text)
# Out:
# 好的，這是一份關於阿波羅11號任務空對地語音通訊（GOSS NET 1）內容的繁體中文統整：
#
# ---
#
# **阿波羅11號空對地語音通訊（GOSS NET 1）內容統整**
#
# **任務介紹**
# 這份文件是阿波羅11號任務期間的技術性空對地語音通訊（GOSS NET 1）謄本。通訊參與者包括：
# *   **太空載具成員**：指令長（CDR）尼爾·阿姆斯壯、指令艙駕駛員（CMP）麥可·柯林斯、登月艙駕駛員（LMP）艾德溫·艾德林二世。
# *   **任務控制中心**：太空艙通訊員（CC）、飛行主任（F）。
# *   **遠端站點**：通訊技術員（CT）。
# *   **回收部隊**：大黃蜂號航空母艦（HORNET）、回收直升機（R）、空勤長（AB）。
#
# 謄本中，三個點（...）表示因語音模糊而無法轉錄的部分，一個破折號（-）表示說話者暫停或自我打斷，兩個破折號（--）表示被他人打斷或錄音突然終止。
#
# ---
#
# **第一部分：發射與地月轉移**
#
# *   **發射與近地軌道插入 (GET 00:00:00 - 00:12:06)**
#     *   指令長（CDR）確認時鐘啟動並執行滾轉程式，隨後確認滾轉完成及俯仰程式設定。
#     *   任務控制中心（CC）多次確認飛行狀態「許可」（GO），包括發射後1分鐘、4分鐘、5分鐘及6分鐘的狀態檢查。
#     *   太空載具成功完成第二級脫離、點火、裙部分離及逃逸塔拋棄。
#     *   太空載具確認在7分鐘時一切正常，並在8分鐘時導引系統收斂，遙測數據良好。
#     *   指令長報告天氣狀況良好，確認視覺系統正常運作。
#     *   CC確認太空載具「許可」進行第二級分離（staging）及點火。
#     *   太空載具報告第二級關機，並確認進入101.4 x 103.6海里（約187.8 x 191.9公里）的地球軌道。
#     *   任務控制中心確認太空載具「許可」進入地球軌道。
#
# *   **地月轉移軌道點火準備 (GET 00:12:06 - 01:00:00)**
#     *   助推器被設定為軌道滑行模式。
#     *   太空載具與多個遠端地面站點（如Vanguard、Canary、Tananarive、Carnarvon、Honeysuckle）建立通訊，確認系統正常，並接收導引參數更新。
#     *   指令艙通訊員（CC）向太空人提供Delta方位角修正及P52校準建議，太空人確認執行。
#     *   太空人對地面通訊質量表示讚賞，地面也確認收到清晰通訊。
#     *   太空人報告發現服務艙RCS Bravo四軸推進器加熱器開關未在PRIMARY位置，隨後修正，溫度恢復正常。
#     *   通訊中，太空人提及雷達數據顯示軌道為103.0 x 103.0海里（約190.8 x 190.8公里）。
#     *   任務控制中心確認飛行器狀態良好，有99%以上的機會能正確關機，且初期電視畫面也顯示系統運作正常。
#     *   阿波羅11號在進入地月轉移軌道時，太空人描述了壯麗的地球景色，包括北美洲、北大西洋、歐洲及北非的清晰視野。
#
# *   **探測器伸出與RCS熱點火測試 (GET 01:39:54 - 01:43:40)**
#     *   太空人報告準備好伸出對接探測器，並在任務控制中心監測下進行RCS熱點火測試。
#     *   指令長確認所有三軸推進器（俯仰、偏航、滾轉）點火正常，但太空人無法聽到點火聲音。
#     *   CC確認遙測數據顯示點火正常。
#     *   太空人隨後確認序列邏輯（sequence logic）開啟並處於「許可」狀態。
#
# *   **地月轉移軌道點火 (GET 02:43:18 - 02:55:28)**
#     *   任務控制中心在點火前確認一切準備就緒。
#     *   指令長報告點火，CC確認點火成功，推力「許可」。
#     *   飛行中數據顯示軌跡、導引及級間狀態良好。
#     *   太空人報告土星五號運載火箭提供了「壯觀的飛行」，各級表現完美，沒有顯著的瞬態。
#     *   任務控制中心向太空載具傳達了S-IVB分離機動的預計時間（3時05分03秒開始，3時09分20秒完成，3時15分03秒分離）。
#
# ---
#
# **第二部分：月球轉移與月軌操作**
#
# *   **指令艙與登月艙轉向對接 (GET 03:05:28 - 03:51:13)**
#     *   任務控制中心確認S-IVB級關機初步數據良好。
#     *   通訊中斷後重新建立，任務控制中心發現一組熱引信匯流排未啟用。
#     *   太空載具收到「許可」分離指令。
#     *   指令長（CDR）確認分離完成，並報告Bravo四軸推進器的主次級推進劑都顯示異常讀數（barber pole）。任務控制中心確認收到。
#     *   太空人嘗試在艙內進行氣壓均衡，發現艙壓（4.4 psi）略低於預期（5 psi），任務控制中心確認可繼續。
#     *   地面建議太空人預防性地循環服務艙輔助推進劑二次加壓閥。
#     *   太空人觀測到助推器進行非推進劑排氣，形成煙霧狀，並有小顆粒隨之漂浮。
#     *   指令長描述了從太空看到的壯麗地球全景，並提到這是「非常好的景色」。
#     *   確認12個對接鎖扣已鎖定。
#     *   收到逃逸機動（evasive maneuver）指令包（PAD），用於避開S-IVB級。
#     *   LM（登月艙）彈射得到許可，彈射後出現Cryo壓力燈亮起，按指示開啟O2風扇並將加熱器設為自動。
#     *   RCS推進劑消耗量略低於預期，但無問題。
#
# *   **S-IVB 級觀察與軌道維護 (GET 04:37:40 - 05:05:18)**
#     *   確認俯仰萬向節馬達關閉。
#     *   太空人開始機動觀察S-IVB級的「彈弓」機動（slingshot）。
#     *   任務控制中心提供了新的觀察姿態數據，並告知中途修正1被取消，因為其所需速度變化極小。
#     *   太空人描述了從太空看到的地球，天氣良好。
#     *   隨後觀測到S-IVB級，距離約數英里，並看到其液氧排氣（LOX dump）。
#
# *   **例行維護與通訊 (GET 05:12:58 - 05:59:55)**
#     *   任務控制中心指示調整太空載具姿態（trunnion bias），並給出氧氣Cryo平衡建議。
#     *   太空人確認Cryo平衡設定，並報告LM/CM氣壓差為0.2。
#     *   進行廢水排放作業。
#     *   太空人與地面人員輕鬆對話，祝賀穆勒博士和加州生日。
#     *   太空人進行光學校準，出現Noun 71及Noun 93讀數較大問題，太空人質疑是否與地平線非對稱有關，任務控制中心建議接受讀數。
#     *   收到地月轉移後11小時的指令包（P37）。
#     *   太空人確認光學校準的滾轉、俯仰、偏航角度，並為夏威夷通訊站做準備。
#
# *   **休息期與通訊問題 (GET 06:09:17 - 00:22:50)**
#     *   任務控制中心白班組上線。
#     *   中途修正1被取消。
#     *   太空人回報萬向節角度問題，但已成功繞過萬向節鎖定。
#     *   Cryo壓力燈亮起並發出主警報，隨後開啟O2風扇解決。
#     *   Noun 49 (Delta-R Delta-V) 數據問題，多次嘗試後接受。
#     *   電池充電時間表調整。
#     *   通訊問題：訊號微弱、卡頓。
#     *   第一次電視傳輸嘗試成功接收約1分鐘畫面。
#     *   設定太空載具姿態進入被動熱控制（PTC）模式。
#     *   冗長的休息期，通訊量減少。
#
# *   **月球軌道插入準備與新聞更新 (GET 00:22:50 - 03:01:24)**
#     *   太空人被叫醒，收到多項更新，包括飛行計畫更新、耗材狀況及晨間新聞。
#     *   飛行計畫中，調整了自駕RCS推進器選擇模式、電池充電時程、廢水排放量及P52校準姿態。
#     *   通訊中斷問題再次出現，地面進行調整。
#     *   耗材更新顯示RCS推進劑、氫氣及氧氣消耗正常。
#     *   CC報告了全球各地對阿波羅11號任務的關注（例如，Luna 15的動向、美國副總統對火星登陸的言論、歐洲各國的慶祝活動等）。
#     *   太空人對SPS發動機的性能進行了詳細討論，特別是板載壓力計讀數與實際腔室壓力之間的差異。
#     *   太空人執行O2和H2燃料電池淨化。
#     *   執行P52校準，並更新LM/CM氣壓差。
#     *   收到月球軌道插入（LOI 1）指令包（PAD）。
#     *   太空人執行P52校準，地面進行遙測數據驗證。
#     *   收到地月轉移後2小時的指令包（P30）。
#     *   太空人確認了水傳感器問題。
#     *   太空人更新了LM/CM氣壓差讀數（約1.1）。
#
# ---
#
# **第三部分：登月與月面活動**
#
# *   **月球軌道插入 (GET 03:03:30 - 03:03:40)**
#     *   任務控制中心確認太空載具「許可」執行月球軌道插入（LOI）。
#     *   指令長確認一切正常，太空載具進入無線電靜默區準備點火。
#
# *   **LOI 點火與月球軌道運行 (GET 03:04:15 - 03:05:38)**
#     *   通訊恢復後，指令長報告月球軌道插入點火順利，殘差極小，且軌道參數良好（60.9 x 169.9海里）。
#     *   太空人描述首次從月球軌道俯瞰月球表面，看到塔倫蒂烏斯、梅西耶等環形山，對真實景象的壯麗感到震撼，並稱其為「身臨其境的體驗」。
#     *   任務控制中心確認初步追蹤數據顯示軌道為61.6 x 169.5海里。
#     *   地面報告SPS系統的氮氣罐壓力略低於預期但保持穩定。
#     *   太空人報告了月球地貌，並提到將進入登月程序。
#
# *   **LM 啟用與檢查 (GET 03:11:09 - 04:03:28)**
#     *   登月艙（LM）啟動並進行通訊檢查，太空人確認通訊良好。
#     *   指令長（CDR）與指令艙駕駛員（CMP）進行時間同步和數據傳輸。
#     *   LGC（登月艙導引電腦）自檢通過，熱點火檢查正常。
#     *   LM起落架伸出。
#     *   RCS推進劑加壓，AGS（輔助導引系統）中止常數輸入。
#     *   攝像機檢查（70毫米和16毫米攝像機均正常）。
#
# *   **登月艙脫離與降軌點火 (GET 04:03:28 - 04:05:25)**
#     *   任務控制中心確認「許可」登月艙脫離。
#     *   指令長確認登月艙成功脫離，「鷹號展翅」（The Eagle has wings）。
#     *   收到降軌點火（DOI）和動力下降點火（PDI）指令包（PAD）。
#     *   指令艙與登月艙之間的VHF測距建立。
#     *   任務控制中心提供多項指令包更新，包括LM狀態向量、CSM救援PAD和月面數據PAD。
#     *   登月艙執行P52校準，並進行RCS熱點火檢查，一切正常。
#
# *   **動力下降與登月 (GET 04:06:28 - 04:06:46)**
#     *   任務控制中心確認「許可」動力下降。
#     *   太空人報告「程序警報」（PROGRAM ALARM），但任務控制中心確認可以繼續。
#     *   登月艙下降過程中，太空人不斷報告高度、速度、俯仰角度等參數，並與地面確認數據。
#     *   指令長確認了與預期軌跡的偏差，決定手動控制以避開岩石區。
#     *   著陸雷達鎖定成功，高度燈熄滅。
#     *   太空人持續手動調整下降姿態，選擇著陸點。
#     *   **「接觸燈亮」（CONTACT LIGHT）**。
#     *   **「引擎關機」（ENGINE STOP）**。
#     *   **指令長尼爾·阿姆斯壯報告：「休士頓，這裡是寧靜海基地，鷹號已著陸。」** （Houston, Tranquility Base here. The Eagle has landed.）
#     *   任務控制中心欣喜若狂地回應：「收到，寧靜海基地。我們正在拷貝您們的著陸信息，我們這裡有一群人臉都快憋藍了。我們又開始呼吸了。非常感謝。」
#
# *   **月面首次活動與艙外預備 (GET 04:06:46 - 04:12:08)**
#     *   著陸後，登月艙確認「許可」進行T1階段活動。
#     *   太空人描述著陸後月面景象：平坦，環形山和岩石數量多，顏色從淺灰到深灰不等。
#     *   確認著陸點約在目標點以西0.5英里處，並報告著陸後感覺1/6G重力非常自然。
#     *   登月艙進行電力關機和模擬倒數終止。
#     *   太空人請求將艙外活動（EVA）提前至休士頓時間晚上8點，任務控制中心同意支持。
#     *   太空人描述了月面環境的細節：土壤像石墨粉末，岩石表面有氣泡狀或晶體狀，有些岩石露出地表，有些則部分埋藏。
#
# *   **艙外活動 (EVA) - 「那一小步」 (GET 04:12:08 - 04:15:38)**
#     *   太空人穿戴個人生命支持系統（PLSS）並檢查通訊。
#     *   指令長和登月艙駕駛員均確認其通訊正常。
#     *   指令長報告打開電視攝影機，但由於月面陰影，畫面可能受影響。
#     *   指令長尼爾·阿姆斯壯開始從登月艙梯子下降。
#     *   報告月球表面細膩如粉末，腳印深度僅1-2英吋。
#     *   **指令長尼爾·阿姆斯壯踏上月面，說出名言：「這是一個人的一小步，卻是人類的一大步。」** (THAT'S ONE SMALL STEP FOR (A) MAN, ONE GIANT LEAP FOR MANKIND.)
#     *   他描述月面鬆軟、具凝聚力，可以清楚看到鞋印和胎面。
#     *   移動非常容易，比模擬訓練中還要輕鬆。
#     *   下降引擎沒有留下大的撞擊坑，周圍有微不足道的輻射狀條紋。
#     *   安置電視攝影機，並展示其工作狀況。
#     *   收集應急樣本（contingency sample），並描述月球岩石的特性（如氣泡狀、斑晶）。
#     *   地面報告登月艙系統一切正常。
#     *   太空人描述月面的「嚴酷美」，像美國西部高原。
#     *   讀取登月艙登陸架上的紀念牌匾內容：「人類從地球首次踏足月球，西元1969年7月。我們為全人類的和平而來。」並有太空人及美國總統簽名。
#     *   登月艙駕駛員艾德林開始下降梯子。
#     *   艾德林描述在月球上移動的方式，包括「袋鼠跳」和改變方向的技巧，發現其背包的慣性影響。
#     *   描述月面光線的對比，陰影下的可見度，以及靴子顏色因灰塵而改變。
#     *   月球上踢動沙土的觀察，它們會以相似的角度和速度拋出，並在特定距離外撞擊。
#     *   總統尼克森從白宮致電問候，祝賀太空人，並強調此次任務對地球和平的意義。
#     *   太空人開始設置太陽風收集器（Solar Wind Composition Experiment）。
#     *   進行全景拍攝，描述月面上的岩石和小型環形山。
#     *   部署被動地震儀（Passive Seismic Experiment），遇到水準儀問題，隨後解決。
#     *   部署雷射測距反射器（Laser Ranging Retroreflector）。
#     *   EVA時間延長15分鐘。
#     *   收集岩石樣本，包括兩個岩心管，並描述其挖掘難度與土壤濕潤感。
#     *   月球表面岩石的顏色描述（無色、灰色、白粉筆般的灰）。
#     *   完成所有科學儀器部署和樣本採集。
#
# *   **艙外活動 (EVA) 結束與返回登月艙 (GET 04:15:38 - 04:18:18)**
#     *   太空人準備結束艙外活動，將樣品和設備裝入樣本返回容器。
#     *   確認已將哈蘇相機的膠捲盒裝入樣本返回容器。
#     *   登月艙駕駛員艾德林返回登月艙。
#     *   指令長尼爾·阿姆斯壯跟隨返回登月艙。
#     *   指令長報告已收集約20磅精選樣本。
#     *   登月艙艙門關閉並鎖定。
#     *   太空人重新加壓登月艙，任務控制中心報告被動地震儀記錄到降落後的震動。
#     *   任務控制中心確認「許可」進行S波段測距，並祝賀太空人「出色完成了任務」。
#     *   地面詢問關於任務計時器問題的解決方案，太空人進行嘗試。
#     *   月面停留期間觀察到的地質問題，以及從月面升空時是否觀察到灰塵。
#     *   任務控制中心要求確認「訊息盤」是否放置在月面，以及所有列出的物品是否都已拋棄。
#
# ---
#
# **第四部分：地球轉移與再入**
#
# *   **地球轉移軌道常規操作 (GET 05:00:59 - 06:03:47)**
#     *   太空人被叫醒，報告前一晚休息良好。
#     *   收到多項飛行計畫更新，包括取消中途修正6、電池充電、廢水排放及P52校準。
#     *   收到最新的耗材數據。
#     *   收到再入指令包（PAD）。
#     *   太空人檢查心電圖讀數問題（因電極乾燥導致）。
#     *   太空載具離開月球引力影響範圍。
#     *   收到最新的新聞報導，內容包括全球對阿波羅11號的持續關注、Luna 15墜毀、太空人親屬的反應，以及太空人在太空對地球的觀察。
#     *   太空人描述了地球的壯麗景象，從太空看到的陸地、海洋和天氣模式。
#     *   太空人進行了幽默的廣播，展示了如何在零重力下吃東西、喝水，並玩弄陀螺儀。
#     *   太空人報告了登月艙/指令艙對接期間的異常滾轉活動，以及SPS引擎點火時的瞬態問題。
#     *   太空載具進入被動熱控制（PTC）模式，並解決了PTC啟動過程中的速率問題。
#     *   指令艙內的溫度變化報告（略低於以往）。
#     *   指令艙RCS推進器溫度檢查。
#     *   描述了LM/CM隧道區域的濕氣問題。
#     *   70毫米相機的使用情況報告。
#
# *   **再入準備 (GET 07:07:14 - 07:22:19)**
#     *   太空人收到「Change Lima」指令，更新了再入操作清單，增加了在主傘展開後排空氧氣歧管的步驟。
#     *   收到全明星賽結果（美聯負國聯）。
#     *   通訊中，太空人與地面人員輕鬆交流，討論家裡草坪的狀況、蚊子、天氣預報（回收區天氣良好）等。
#     *   確認了EVA頭盔面罩的存放位置，並調整了再入瞄準點以適應天氣狀況。
#     *   確認中途修正7被取消。
#     *   收到再入指令包更新。
#     *   太空人確認雷射測距反射器已被地面望遠鏡觀測到。
#
# *   **最終再入與濺落 (GET 08:01:01 - 08:03:18)**
#     *   太空人準備進行最終再入，啟動必要系統，並進行通訊檢查。
#     *   確認指令艙RCS系統加壓正常，並準備拋棄服務艙。
#     *   太空人收到最終的再入指令包（PAD）更新。
#     *   服務艙成功分離，太空人描述其旋轉和噴氣狀況。
#     *   通訊中斷，進入黑障區。
#     *   **任務控制中心確認引導傘已展開。**
#     *   **阿波羅11號與回收部隊（大黃蜂號航空母艦，直升機）建立通訊。**
#     *   **報告太空載具位置、機組人員狀況。**
#     *   **報告主傘展開高度（2500英尺）。**
#     *   **回收直升機（SWIM 1）確認目視接觸太空載具。**
#     *   **任務控制中心確認濺落成功！** (SPLASHDOWN!)
#
# ---

# %% [markdown]
# ## V. 類型配置

# %%
response = client.models.generate_content(
    model='gemini-2.0-flash',
    contents=types.Part.from_text(text='請問為何天空是藍色的？'),
    config=types.GenerateContentConfig(
        temperature=0,
        top_p=0.95,
        top_k=20,
        candidate_count=1,
        seed=5,
        max_output_tokens=100,
        stop_sequences=['STOP!'],
        presence_penalty=0.0,
        frequency_penalty=0.0,
    ),
)

print(response.text)
# Out:
# None

# %% [markdown]
# ## Model List

# %%
for model in client.models.list():
    print(model.name)
# Out:
# models/embedding-gecko-001
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-2.5-flash-lite
# models/embedding-001
# models/text-embedding-004
# models/gemini-embedding-exp-03-07
# models/gemini-embedding-exp
# models/gemini-embedding-001
# models/aqa
# models/imagen-3.0-generate-002
# models/imagen-4.0-generate-preview-06-06
# models/imagen-4.0-ultra-generate-preview-06-06
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-preview
# models/veo-3.0-fast-generate-preview
# models/gemini-2.5-flash-preview-native-audio-dialog
# models/gemini-2.5-flash-exp-native-audio-thinking-dialog
# models/gemini-2.0-flash-live-001
# models/gemini-live-2.5-flash-preview
# models/gemini-2.5-flash-live-preview

# %% [markdown]
# ## V. Function Calling
#
# 此處示範，統整所有行政院最新新聞消息的 function calling。
#
# API 位置：https://opendata.ey.gov.tw/api/index.html

# %%
from typing import List, Union
from datetime import datetime, date
import requests

def normalize_date(date_str: Union[str, date]) -> str:
    """將輸入轉為 'YYYY/MM/DD' 字串格式"""
    if isinstance(date_str, date):
        return date_str.strftime('%Y/%m/%d')
    try:
        parsed = datetime.strptime(date_str, '%Y-%m-%d')
        return parsed.strftime('%Y/%m/%d')
    except ValueError:
        return date_str  # 假設已是 YYYY/MM/DD

def get_ey_news(start_date: str, end_date: str) -> List[dict]:
    """取得行政院公開新聞資料"""
    start_date_fmt = normalize_date(start_date)
    end_date_fmt = normalize_date(end_date)

    url = "https://opendata.ey.gov.tw/api/ExecutiveYuan/NewsEy"
    params = {
        "StartDate": start_date_fmt,
        "EndDate": end_date_fmt,
        "MaxSize": 10,
        "IsRemoveHtmlTag": True
    }
    response = requests.get(url, params=params)
    response.raise_for_status()
    return response.json()

# %%
output = get_ey_news("2025/07/01", "2025/07/31")
output[0]

# %%
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents="幫我找 2025/04/01 至 2025/04/30 行政院發布的新聞標題和發佈時間",
    config=types.GenerateContentConfig(tools=[get_ey_news]),
)

print(response.text)
# Out:
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# 很抱歉，目前無法取得行政院新聞資料，請您稍後再試。

# %% [markdown]
# ## VII. Pydantic-JSON 回應架構

# %%
from pydantic import BaseModel


class CountryInfo(BaseModel):
    name: str
    population: int
    capital: str
    continent: str
    gdp: int
    official_language: str
    total_area_sq_mi: int


response = client.models.generate_content(
    model='gemini-2.0-flash',
    contents='請給我台灣的相關資訊',
    config=types.GenerateContentConfig(
        response_mime_type='application/json',
        response_schema=CountryInfo,
    ),
)
print(response.text)
# Out:
# {
#   "name": "Taiwan",
#   "population": 23570000,
#   "capital": "Taipei",
#   "continent": "Asia",
#   "gdp": 759100000000,
#   "official_language": "Mandarin Chinese",
#   "total_area_sq_mi": 13974
# }

# %% [markdown]
# ## VIII. Streaming Output

# %%
for chunk in client.models.generate_content_stream(
    model='gemini-2.0-flash', contents='請用100字講一個大野狼的故事'
):
    print(chunk.text, end='')
# Out:
# 飢餓的大野狼在森林裡遊蕩，巧遇三隻小豬蓋房子。他先後吹倒了草屋和木屋，吞掉了兩隻小豬。最後，他來到磚房前，使盡全力也吹不動。
#
# 惱羞成怒的大野狼爬上屋頂，想從煙囪溜進去。聰明的小豬早已在壁爐裡煮沸了一大鍋水。大野狼滑進煙囪，正好掉進滾燙的熱水裡，慘叫一聲，便結束了他罪惡的一生。

# %% [markdown]
# ## 生成圖片

# %%
import base64
import mimetypes
from IPython.display import Image, display

def display_binary_image(mime_type, data):
    display(Image(data=data))

model = "gemini-2.0-flash-preview-image-generation"
contents = [
    types.Content(
        role="user",
        parts=[
            types.Part.from_text(text="""繪製一隻皮卡丘，站在噴火龍身上。"""),
        ],
    ),
]

generate_content_config = types.GenerateContentConfig(
    response_modalities=[
        "image",
        "text",
    ],
    response_mime_type="text/plain",
)

for chunk in client.models.generate_content_stream(
    model=model,
    contents=contents,
    config=generate_content_config,
):
    if not chunk.candidates or not chunk.candidates[0].content or not chunk.candidates[0].content.parts:
        continue
    if chunk.candidates[0].content.parts[0].inline_data:
        inline_data = chunk.candidates[0].content.parts[0].inline_data
        mime_type = inline_data.mime_type
        binary_data = inline_data.data
        # 直接顯示圖片
        display_binary_image(mime_type, binary_data)
        print(f"Image of mime type {mime_type} displayed.")
    else:
        print(chunk.text)
# Out:
# 我
# 將繪製一隻黃色的皮卡丘，它有著紅色的
# 臉頰和黑色的尖耳朵，神氣地站立在一隻巨大的橘紅色噴火龍背上，噴火龍正以堅定的眼神望向前方。
# Image of mime type image/png displayed.
